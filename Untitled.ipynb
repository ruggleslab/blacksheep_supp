# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/lili/Downloads/Andrew+Lili Wedding Guest List - Guest List Contact Info.csv')

# %%
df = df.dropna(subset=['Address Line 1'])

# %%
df.loc[df['Country'].isnull(), 'Country'] = np.nan
# Out:
# /Users/lili/anaconda3/envs/blacksheep/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
nofam_name = df.loc[df['Family Name'].isnull(), :]
fam_name = df.loc[df['Family Name'].isnull()==False, :]

# %%
nofam_name['Family Name'] = nofam_name['Last Name']
# Out:
# /Users/lili/anaconda3/envs/blacksheep/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
nofam_name
# Out:
#                 Name  Email  Address    Family Name       First Name  \
# 90              Adam    NaN      NaN            NaN              NaN
# 92              Beca    NaN      NaN        Nikolic              NaN
# 95             Jutka    NaN      NaN      Jovanovic           Judita
# 96             Djole    NaN      NaN      Jovanovic          Djordje
# 98             Vlado    NaN      NaN     Blumenberg            Vlado
# 100            Livia    NaN      NaN      Wuethrich           Livija
# 102             Judy    NaN      NaN           Lynn             Judy
# 104            Suzie    NaN      NaN        Lambert            Susan
# 107          Mirjana    NaN      NaN       Mladinov          Mirjana
# 109           Branca    NaN      NaN       Bogdanov           Branca
# 110          Marjana    NaN      NaN          Camic          Marjana
# 114          Sabrina    NaN      NaN            NaN              NaN
# 116             Nick    NaN      NaN      Racheotes             Nick
# ...
